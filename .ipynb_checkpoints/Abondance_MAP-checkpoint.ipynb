# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score, confusion_matrix, classification_report
from sklearn.model_selection import learning_curve
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import SelectKBest, f_classif, RFE, RFECV
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer
from sklearn.decomposition import PCA

# %%
path = "C:/Users/tamer/Documents/PhD/ML/Metabolome_HM.xlsx"
df = pd.read_excel(path)

df = df.groupby('Class').mean()
df = df.reset_index()

# %%
def encodage(df):
    code = {
    'LP' : 'Lemon\ninoculated',
    'SP' : 'Orange\ninoculated',
    'LN' : 'Lemon\ncontrol',
    'SN' : 'Orange\ncontrol'
}
    # Appliquer ce dictionnaire aux colonnes du dataset, avec la fonction map
    for col in df.select_dtypes('object'):
        df[col] = df[col].map(code)

    return df

encodage(df)
df = df.set_index('Class')
print(df.shape)
df.head()
# Out:
# (4, 384)
#                     (-)-Caryophyllene oxide  (-)-Citronellal  (-)-Isopulegol  \
# Class
# Lemon\ncontrol                 1.591455e+07     6.980138e+07    5.631014e+07
# Lemon\ninoculated              2.952731e+07     4.659259e+07    1.455664e+08
# Orange\ncontrol                3.621271e+06     1.318311e+07    3.954817e+06
# Orange\ninoculated             6.650474e+06     5.141848e+06    4.719063e+06
#
#                     (+/-)-6-Acetonyldihydrosanguinarine  (+/-)9-HpODE  \
# Class
# Lemon\ncontrol                             1.449034e+08  4.335375e+06
# Lemon\ninoculated                          1.789006e+08  8.626689e+06
# Orange\ncontrol                            5.627351e+07  3.468366e+07
# Orange\ninoculated                         6.386797e+07  2.463304e+07
#
#                     (12Z)-9,10,11-trihydroxyoctadec-12-enoic acid  \
# Class
# Lemon\ncontrol                                       8.535153e+06
# Lemon\ninoculated                                    8.261674e+06
# Orange\ncontrol                                      4.204084e+06
# Orange\ninoculated                                   6.653567e+06
#
#                     (13S,14R)-1,8-Dihydroxy-13-O-acetyl-N-methylcanadine  \
# Class
# Lemon\ncontrol                                           1.766983e+06
# Lemon\ninoculated                                        1.720943e+06
# Orange\ncontrol                                          9.390267e+06
# Orange\ninoculated                                       1.203525e+07
#
#                     (1R,2R)-3-oxo-2-pentyl-cyclopentanebutanoic acid  \
# Class
# Lemon\ncontrol                                          2.648956e+08
# Lemon\ninoculated                                       2.538358e+08
# Orange\ncontrol                                         8.327545e+08
# Orange\ninoculated                                      1.060611e+09
#
#                     (20S,24S)-24-ethylthornasterol  \
# Class
# Lemon\ncontrol                        4.355494e+06
# Lemon\ninoculated                     1.398658e+06
# Orange\ncontrol                       1.263292e+07
# Orange\ninoculated                    4.606290e+06
#
#                     (2R,3S,4S,5R,6R)-2-(hydroxymethyl)-6-(2-phenylethoxy)oxane-3,4,5-triol  \
# Class
# Lemon\ncontrol                                           9.664745e+06
# Lemon\ninoculated                                        1.363532e+07
# Orange\ncontrol                                          6.627322e+06
# Orange\ninoculated                                       1.585956e+07
#
#                     ...  3-O-Feruloylquinic acid     Coniferin  \
# Class               ...
# Lemon\ncontrol      ...             2.511707e+08  6.939086e+06
# Lemon\ninoculated   ...             2.769312e+08  1.412598e+07
# Orange\ncontrol     ...             6.432403e+05  1.595483e+06
# Orange\ninoculated  ...             1.160512e+06  5.709360e+06
#
#                     Deoxylimononic acid D-ring-lactone  Ferulaldehyde  \
# Class
# Lemon\ncontrol                            9.162016e+06   9.633634e+06
# Lemon\ninoculated                         1.032705e+07   2.302739e+07
# Orange\ncontrol                           3.026178e+05   2.108045e+06
# Orange\ninoculated                        2.334481e+05   2.683576e+06
#
#                         Marmesin  Methyl eugenol  Naringenin chalcone  \
# Class
# Lemon\ncontrol      1.243857e+06    1.430837e+07         4.043855e+05
# Lemon\ninoculated   3.747008e+05    1.629475e+07         9.016501e+05
# Orange\ncontrol     6.058752e+06    6.325601e+06         1.799970e+07
# Orange\ninoculated  7.488058e+06    6.642415e+06         1.396005e+07
#
#                     Neohesperidin    Phloridzin  trans-Anethole
# Class
# Lemon\ncontrol       9.217758e+05  1.039302e+05    9.407254e+06
# Lemon\ninoculated    2.773134e+06  8.109454e+04    1.632331e+07
# Orange\ncontrol      1.997852e+07  6.915266e+06    3.236706e+07
# Orange\ninoculated   1.816003e+07  1.907657e+06    1.899205e+07
#
# [4 rows x 384 columns]

# %%
print('var before log2 : ', df.var(axis=0).median())
log2_transformer = FunctionTransformer(lambda x: np.log2(x + 1))
df = log2_transformer.fit_transform(df)
print('var after log2 : ', df.var(axis=0).median())
df['Coniferin']
# Out:
# var before log2 :  192081264227026.03
# var after log2 :  2.3312598503748583
# Class
# Lemon\ncontrol        22.726314
# Lemon\ninoculated     23.751847
# Orange\ncontrol       20.605563
# Orange\ninoculated    22.444898
# Name: Coniferin, dtype: float64

# %%
ca = ["Syringin",
"Coniferin",
"Methyl eugenol",
"L-Phenylalanine",
"L-Tyrosine",
"Cinnamic acid",
"p-Coumaric acid",
"Ferulic acid",
"Sinapic acid",
"Ferulaldehyde"
]

cm = ["Marmesin",
"Scopolin",
"Scopoletin",
"Esculetin",
"Heraclenol",
"7-Demethylsuberosin",
"Isopimpinellin",
"Byakangelicin",
"Imperatorin",
"Xanthotoxol",
"Byakangelicol",
"Phellopterin"
]

fn = ["Baimaside",
"Naringenin chalcone",
"Lonicerin",
"Rhoifolin",
"Apigenin",
"Vitexin",
"Isovitexin",
"Vitexin rhamnoside",
"Quercetin",
"Rutin",
"Quercitrin",
"Isoquercitrin",
"Apigetrin",
"Cynaroside",
"Astragalin",
"Kaempferol",
"Nicotiflorin"
]


ln = ["Deoxylimononic acid D-ring-lactone",
"Glucosyl-limonin",
"Limonin",
"Limonoate",
"Nomilin",
"Obacunoic acid",
"Obacunone"
]


bm = ["Indole-3-acetic acid",
"Malonyldaidzin",
"Pectolinarigenin",
"Zeatin-7-N-glucoside",
"Chrysosplenetin B",
"Lysionotin",
"Hesperidin",
"Diosmetin",
"6-Methoxykaempferol 3-rhamnoside-7-(4'''-acetylrhamnoside)",
"Lawsone",
"Hellicoside",
"(-)-Isopulegol",
"Hispidulin 7-(6''-E-p-Coumaroylglucoside)",
"Dihydrolycorine",
"Phenylacetaldehyde",
"5,2'-Dihydroxy-6,7,8,6'-tetramethoxyflavone",
"Isoalangiside",
"Vicenin II",
"Ranaconitine",
"Wogonoside",
"Strigolactone ABC-rings",
"Colchicoside",
"Rehmannioside C",
"Limocitrol 3-alpha-L-arabinopyranosyl-(1->3)-galactoside",
"Jaceosidin",
"Genistein 7,4'-bis(O-glucosylapioside)",
"Vismione D",
"Ligustroflavone",
"Thapsigargin",
"Methyl hesperidin",
"Diosbulbin B",
"Didymin",
"Adiantifoline",
"Senkirkine",
"Luteolin 7-(6''-p-benzoyglucoside)",
"trans-Aconitic acid",
"Kaempferol 3-apiosyl-(1->4)-rhamnoside-7-rhamnoside",
"2-Oxo-turkesterone",
"Osthenol-7-O-beta-D-gentiobioside",
"(E)-3-methyl-6-(pent-3-en-1-yn-1-yl)-1,2-dithiine",
"4,5-Dicaffeoylquinic acid",
"Myricoside",
"Thalicarpine"]

# %%
df.head()
# Out:
#                     (-)-Caryophyllene oxide  (-)-Citronellal  (-)-Isopulegol  \
# Class
# Lemon\ncontrol                    23.923843        26.056752       25.746891
# Lemon\ninoculated                 24.815546        25.473597       27.117102
# Orange\ncontrol                   21.788065        23.652188       21.915180
# Orange\ninoculated                22.665026        22.293856       22.170069
#
#                     (+/-)-6-Acetonyldihydrosanguinarine  (+/-)9-HpODE  \
# Class
# Lemon\ncontrol                                27.110516     22.047726
# Lemon\ninoculated                             27.414583     23.040376
# Orange\ncontrol                               25.745953     25.047753
# Orange\ninoculated                            25.928589     24.554091
#
#                     (12Z)-9,10,11-trihydroxyoctadec-12-enoic acid  \
# Class
# Lemon\ncontrol                                          23.024986
# Lemon\ninoculated                                       22.978003
# Orange\ncontrol                                         22.003360
# Orange\ninoculated                                      22.665697
#
#                     (13S,14R)-1,8-Dihydroxy-13-O-acetyl-N-methylcanadine  \
# Class
# Lemon\ncontrol                                              20.752857
# Lemon\ninoculated                                           20.714769
# Orange\ncontrol                                             23.162735
# Orange\ninoculated                                          23.520762
#
#                     (1R,2R)-3-oxo-2-pentyl-cyclopentanebutanoic acid  \
# Class
# Lemon\ncontrol                                             27.980848
# Lemon\ninoculated                                          27.919320
# Orange\ncontrol                                            29.633316
# Orange\ninoculated                                         29.982249
#
#                     (20S,24S)-24-ethylthornasterol  \
# Class
# Lemon\ncontrol                           22.054405
# Lemon\ninoculated                        20.415613
# Orange\ncontrol                          23.590685
# Orange\ninoculated                       22.135174
#
#                     (2R,3S,4S,5R,6R)-2-(hydroxymethyl)-6-(2-phenylethoxy)oxane-3,4,5-triol  \
# Class
# Lemon\ncontrol                                              23.204300
# Lemon\ninoculated                                           23.700846
# Orange\ncontrol                                             22.659995
# Orange\ninoculated                                          23.918849
#
#                     ...  3-O-Feruloylquinic acid  Coniferin  \
# Class               ...
# Lemon\ncontrol      ...                27.904093  22.726314
# Lemon\ninoculated   ...                28.044953  23.751847
# Orange\ncontrol     ...                19.295001  20.605563
# Orange\ninoculated  ...                20.146331  22.444898
#
#                     Deoxylimononic acid D-ring-lactone  Ferulaldehyde  \
# Class
# Lemon\ncontrol                               23.127234      23.199649
# Lemon\ninoculated                            23.299926      24.456848
# Orange\ncontrol                              18.207142      21.007475
# Orange\ninoculated                           17.832748      21.355726
#
#                      Marmesin  Methyl eugenol  Naringenin chalcone  \
# Class
# Lemon\ncontrol      20.246390       23.770356            18.625375
# Lemon\ninoculated   18.515383       23.957904            19.782210
# Orange\ncontrol     22.530589       22.592771            24.101470
# Orange\ninoculated  22.836160       22.663277            23.734800
#
#                     Neohesperidin  Phloridzin  trans-Anethole
# Class
# Lemon\ncontrol          19.814058   16.665269       23.165342
# Lemon\ninoculated       21.403087   16.307335       23.960431
# Orange\ncontrol         24.251946   22.721353       24.948023
# Orange\ninoculated      24.114263   20.863371       24.178892
#
# [4 rows x 384 columns]

# %%
df_ca = df[ca]
df_cm = df[cm]
df_fn = df[fn]
df_ln = df[ln]
df_bm = df[bm]

# %%
color = 'vlag'

# %%
#color = sns.color_palette("Spectral", as_cmap=True)

g = sns.clustermap(df_ca.T,
                   cmap= color,
                   col_cluster = False,
                   #standard_scale=0,
                   z_score=0,
                   center=0,
                   linewidths=0.5,
                   linecolor="black")

plt.setp(g.ax_heatmap.get_xticklabels(), fontsize=14) 
plt.setp(g.ax_heatmap.get_yticklabels(), fontsize=16)

g.ax_heatmap.set_xlabel("")

plt.savefig("C:/Users/tamer/Documents/PhD/ML/Heatmap/CA_heatmap.pdf", format="pdf", bbox_inches="tight")   
plt.savefig("C:/Users/tamer/Documents/PhD/ML/Heatmap/CA_heatmap.png", dpi=600, bbox_inches="tight")   

g.cax.tick_params(labelsize=10)

plt.show()

# %%
#color = sns.color_palette("Spectral", as_cmap=True)

g = sns.clustermap(df_cm.T,
                   cmap= color,
                   col_cluster = False,
                   #standard_scale=0,
                   z_score=0,
                   center=0,
                   linewidths=0.5,
                   linecolor="black")

plt.setp(g.ax_heatmap.get_xticklabels(), fontsize=14) 
plt.setp(g.ax_heatmap.get_yticklabels(), fontsize=16)

g.ax_heatmap.set_xlabel("")

plt.savefig("C:/Users/tamer/Documents/PhD/ML/Heatmap/coumarins_heatmap.pdf", format="pdf", bbox_inches="tight")   
plt.savefig("C:/Users/tamer/Documents/PhD/ML/Heatmap/coumarins_heatmap.png", dpi=600, bbox_inches="tight")   

g.cax.tick_params(labelsize=10)

plt.show()

# %%
#color = sns.color_palette("Spectral", as_cmap=True)

g = sns.clustermap(df_fn.T,
                   cmap= color,
                   col_cluster = False,
                   #standard_scale=0,
                   z_score=0,
                   center=0,
                   linewidths=0.5,
                   linecolor="black")

plt.setp(g.ax_heatmap.get_xticklabels(), fontsize=14) 
plt.setp(g.ax_heatmap.get_yticklabels(), fontsize=16)

g.ax_heatmap.set_xlabel("")

plt.savefig("C:/Users/tamer/Documents/PhD/ML/Heatmap/flavonoids_heatmap.pdf", format="pdf", bbox_inches="tight")   
plt.savefig("C:/Users/tamer/Documents/PhD/ML/Heatmap/flavonoids_heatmap.png", dpi=600, bbox_inches="tight")   

g.cax.tick_params(labelsize=10)

plt.show()

# %%
#color = sns.color_palette("Spectral", as_cmap=True)

g = sns.clustermap(df_ln.T,
                   cmap= color,
                   col_cluster = False,
                   #standard_scale=0,
                   z_score=0,
                   center=0,
                   linewidths=0.5,
                   linecolor="black")

plt.setp(g.ax_heatmap.get_xticklabels(), fontsize=14) 
plt.setp(g.ax_heatmap.get_yticklabels(), fontsize=16)

g.ax_heatmap.set_xlabel("")

plt.savefig("C:/Users/tamer/Documents/PhD/ML/Heatmap/Limonoids_heatmap.pdf", format="pdf", bbox_inches="tight")   
plt.savefig("C:/Users/tamer/Documents/PhD/ML/Heatmap/Limonoids_heatmap.png", dpi=600, bbox_inches="tight")   

g.cax.tick_params(labelsize=10)

plt.show()

# %%
#color = sns.color_palette("Spectral", as_cmap=True)

g = sns.clustermap(df_bm.T,
                   cmap= color,
                   col_cluster = False,
                   #standard_scale=0,
                   z_score=0,
                   center=0,
                   linewidths=0.5,
                   linecolor="black")

plt.setp(g.ax_heatmap.get_xticklabels(), fontsize=14) 
plt.setp(g.ax_heatmap.get_yticklabels(), fontsize=16)

g.ax_heatmap.set_xlabel("")

plt.savefig("C:/Users/tamer/Documents/PhD/ML/Heatmap/biomarkers_heatmap.pdf", format="pdf", bbox_inches="tight")   
plt.savefig("C:/Users/tamer/Documents/PhD/ML/Heatmap/biomarkers_heatmap.png", dpi=600, bbox_inches="tight")   

g.cax.tick_params(labelsize=10)

plt.show()

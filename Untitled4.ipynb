# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


CN93 = [0.54,1.83,-0.29,-0.11,1.38,0.33,0.74,0.03,-0.06,-0.22,0.86,-1.53]
CN93_h = [-0.309326518, -1.054946508, -0.608405935, -0.189169572, -0.961298895, 0.72938863, 0.232492123, 2.422063844, -0.39892041, -0.852005114, -0.759158094, -1.755537481]

# Example pseudo-code
df = pd.DataFrame({
    "CN093": [0.54,1.83,-0.29,-0.11,1.38,0.33,0.74,0.03,-0.06,-0.22,0.86,-1.53],
    "CN093_healthy": [-0.309326518, -1.054946508, -0.608405935, -0.189169572, -0.961298895, 0.72938863, 0.232492123, 2.422063844, -0.39892041, -0.852005114, -0.759158094, -1.755537481],
    "stage": ["early"]*3 + ["mid"]*3 + ["late"]*3 + ["very_late"]*3
})
sns.boxplot(data=df, x="stage", y="CN093")
sns.boxplot(data=df, x="stage", y="CN093_healthy")
sns.pointplot(data=df, x="stage", y="CN093", color="red")
sns.pointplot(data=df, x="stage", y="CN093_healthy", color="red")
plt.show()

# %%
A = [0.54,1.83,-0.29]
B = [-0.309326518, -1.054946508, -0.608405935]

# %%
stats.ttest_ind(CN93, CN93_h)
# Out:
# TtestResult(statistic=np.float64(1.4662664236460177), pvalue=np.float64(0.15672457181780747), df=np.float64(22.0))

# %%
from scipy import stats

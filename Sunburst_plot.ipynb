# %%
import plotly.graph_objects as go
import plotly.express as px

# %% [markdown]
# # Lemon vs orange HLB

# %%
labels = [
'Phenylpropanoids',
'Terpenoids',
'Alkaloids',
'Organic acids',
'Lipids',
'Quinone',
'Benzenoids',
'Others',
'Phenylethanoids',
'Carbohydrates',
'Phytohormones',
'Isoquinoline',
'Pyrrolizidines',
'Indoles',
'Diterpenoid alkaloids',
'Aromatic aldehydes',
'Benzoic acids',
'Ketones',
'Flavonoids',
'Cinnamic acids<br>and derivatives',
'Coumarins',
'Tannins',
'Salicylic acid',
'Triterpenoids',
'Monoterpenoids',
'Diterpenoids',
'Sesquiterpenoids',
'Hydroxycinnamic<br>acid esthers',
'Hydroxycinnamic<br>acids',
'Hydroxycinnamic<br>acid glycosides',
'Furanocoumarins',
'Simple coumarins',
'Flavones',
'Flavonols',
'Isoflavonoids',
'Chalcones',
'Flavanones',
'Anthocyanidins',
'Iridioids',
'Limonoids',
'Quassinoids',
'Steroids'
]

parents = [
' ',
' ',
' ',
' ',
' ',
' ',
' ',
' ',
' ',
' ',
' ',
'Alkaloids',
'Alkaloids',
'Alkaloids',
'Alkaloids',
'Benzenoids',
'Benzenoids',
'Benzenoids',
'Phenylpropanoids',
'Phenylpropanoids',
'Phenylpropanoids',
'Phenylpropanoids',
'Phytohormones',
'Terpenoids',
'Terpenoids',
'Terpenoids',
'Terpenoids',
'Cinnamic acids<br>and derivatives',
'Cinnamic acids<br>and derivatives',
'Cinnamic acids<br>and derivatives',
'Coumarins',
'Coumarins',
'Flavonoids',
'Flavonoids',
'Flavonoids',
'Flavonoids',
'Flavonoids',
'Flavonoids',
'Monoterpenoids',
'Triterpenoids',
'Triterpenoids',
'Triterpenoids'
]


values = [
'47',
'22',
'12',
'1',
'3',
'2',
'6',
'4',
'1',
'3',
'1',
'5',
'2',
'1',
'2',
'1',
'3',
'1',
'30',
'6',
'9',
'1',
'1',
'9',
'8',
'2',
'3',
'2',
'2',
'1',
'8',
'1',
'9',
'10',
'5',
'1',
'4',
'1',
'6',
'6',
'1',
'1',
]


fig =go.Figure(go.Sunburst(
    labels=labels,
    parents=parents,
    values=values,
    branchvalues="total"
    #marker=dict(line=dict(color="black", width=1))  # contour noir
    #textinfo="label+value"  # ajouter valeurs
))

# Update layout for tight margin
fig.update_layout(margin = dict(t=0, l=0, r=0, b=0))

fig.update_layout(
    width=900,   # adjust width as needed
    height=900,   # adjust height as needed
    sunburstcolorway=px.colors.qualitative.Safe,
    extendsunburstcolors=True
)

fig.show()

# %% [markdown]
# # Lemon control vs HLB

# %%
labels = [
'Alkaloids',
'Quinone',
'Terpenoids',
'Carbohydrates',
'Others',
'Phenylethanoids',
'Phenylpropanoids',
'Benzenoids',
'Organic acids',
'Lipids',
'Amino acids',
'Lignans',
'Flavonoids',
'Cinnamic acids<br>and derivatives',
'Monoterpenoids',
'Triterpenoids',
'Sesquiterpenoids',
'Isoquinoline',
'Diterpenoid alkaloids',
'Benzoic acids',
'Iridioids',
'Limonoids',
'Flavones',
'Flavonols',
'Flavanols',
'Chalcones',
'Flavanones',
'Hydroxycinnamic<br>acid glycosides',
'Hydroxycinnamic<br>acid esthers',
'Hydroxycinnamic<br>acids'
]


parents = [
' ',
' ',
' ',
' ',
' ',
' ',
' ',
' ',
' ',
' ',
' ',
'Phenylpropanoids',
'Phenylpropanoids',
'Phenylpropanoids',
'Terpenoids',
'Terpenoids',
'Terpenoids',
'Alkaloids',
'Alkaloids',
'Benzenoids',
'Monoterpenoids',
'Triterpenoids',
'Flavonoids',
'Flavonoids',
'Flavonoids',
'Flavonoids',
'Flavonoids',
'Cinnamic acids<br>and derivatives',
'Cinnamic acids<br>and derivatives',
'Cinnamic acids<br>and derivatives'
]


values = [
'3',
'2',
'13',
'8',
'4',
'1',
'19',
'2',
'1',
'3',
'1',
'3',
'13',
'3',
'5',
'6',
'1',
'2',
'1',
'1',
'3',
'5',
'4',
'4',
'1',
'1',
'3',
'1',
'1',
'1'
]


fig =go.Figure(go.Sunburst(
    labels=labels,
    parents=parents,
    values=values,
    branchvalues="total"
    #marker=dict(line=dict(color="black", width=1))  # contour noir
    #textinfo="label+value"  # ajouter valeurs
))

# Update layout for tight margin
fig.update_layout(margin = dict(t=0, l=0, r=0, b=0))

fig.update_layout(
    width=900,   # adjust width as needed
    height=900,   # adjust height as needed
    sunburstcolorway=px.colors.qualitative.Safe,
    extendsunburstcolors=True
)

fig.show()

# %% [markdown]
# # Total metabolome

# %%
labels = [
'Alkaloids',
'Amino acids',
'Benzenoids',
'Carbohydrates',
'Lactone',
'Lipids',
'Nucleic acids',
'Nucleoside',
'Organic acids',
'Others',
'Phenylethanoids',
'Phenylpropanoids',
'Phytohormones',
'Quinone',
'Terpenoids',
'Vitamins',
'Diterpenoid alkaloids',
'Indoles',
'Isoquinolines',
'Pyridines',
'Pyrrolizidines',
'Quinolines',
'Spermidine alakloids',
'Aromatic aldehydes',
'Benzoic acids',
'Ketones',
'Phenolic',
'Fatty acyls',
'Oxylipins',
'Phospholipids',
'Sterols',
'Sphingolipids',
'Cinnamic acids and derivatives',
'Coumarins',
'Flavonoids',
'Lignamide',
'Lignans',
'Stillbenoids',
'Tannins',
'Auxin',
'Cytokinins',
'Jasmonates',
'Salicylic acid',
'Strigolactone',
'Diterpenoids',
'Monoterpenoids',
'Sesquiterpenoids',
'Tetraterpenoids',
'Triterpenoids',
'Hydroxycinnamic acid esthers',
'Hydroxycinnamic acid glycosides',
'Hydroxycinnamic acids',
'Coumarin glycosides',
'Furanocoumarins',
'Simple coumarins',
'Anthocyanidins',
'Chalcones',
'Flavanols',
'Flavanones',
'Flavones',
'Flavonols',
'Isoflavonoids',
'Iridioids',
'Limonoids',
'Quassinoids',
'Saponins'
]


parents = [
' ',
' ',
' ',
' ',
' ',
' ',
' ',
' ',
' ',
' ',
' ',
' ',
' ',
' ',
' ',
' ',
'Alkaloids',
'Alkaloids',
'Alkaloids',
'Alkaloids',
'Alkaloids',
'Alkaloids',
'Alkaloids',
'Benzenoids',
'Benzenoids',
'Benzenoids',
'Benzenoids',
'Lipids',
'Lipids',
'Lipids',
'Lipids',
'Lipids',
'Phenylpropanoids',
'Phenylpropanoids',
'Phenylpropanoids',
'Phenylpropanoids',
'Phenylpropanoids',
'Phenylpropanoids',
'Phenylpropanoids',
'Phytohormones',
'Phytohormones',
'Phytohormones',
'Phytohormones',
'Phytohormones',
'Terpenoids',
'Terpenoids',
'Terpenoids',
'Terpenoids',
'Terpenoids',
'Cinnamic acids and derivatives',
'Cinnamic acids and derivatives',
'Cinnamic acids and derivatives',
'Coumarins',
'Coumarins',
'Coumarins',
'Flavonoids',
'Flavonoids',
'Flavonoids',
'Flavonoids',
'Flavonoids',
'Flavonoids',
'Flavonoids',
'Monoterpenoids',
'Triterpenoids',
'Triterpenoids',
'Triterpenoids'
]


values = [
'24',
'12',
'17',
'24',
'1',
'35',
'7',
'1',
'14',
'17',
'2',
'145',
'8',
'3',
'60',
'4',
'2',
'3',
'3',
'1',
'2',
'1',
'1',
'2',
'8',
'2',
'2',
'16',
'5',
'1',
'2',
'1',
'17',
'19',
'101',
'1',
'4',
'1',
'1',
'1',
'2',
'3',
'1',
'1',
'5',
'24',
'11',
'1',
'17',
'6',
'2',
'7',
'2',
'9',
'8',
'2',
'3',
'1',
'15',
'37',
'35',
'8',
'17',
'8',
'2',
'1'
]


fig =go.Figure(go.Sunburst(
    labels=labels,
    parents=parents,
    values=values,
    branchvalues="total"
    #marker=dict(line=dict(color="black", width=1))  # contour noir
    #textinfo="label+value"  # ajouter valeurs
))

# Update layout for tight margin
fig.update_layout(margin = dict(t=0, l=0, r=0, b=0))

fig.update_layout(
    width=900,   # adjust width as needed
    height=900,   # adjust height as needed
    sunburstcolorway=px.colors.qualitative.D3,
    extendsunburstcolors=True
)

fig.show()

# %% [markdown]
# # Total metabolome - simplified

# %%
labels = [
'Secondary',
'Primary',
'Alkaloids',
'Amino acids',
'Benzenoids',
'Carbohydrates',
'Lactone',
'Lipids',
'Nucleic acids',
'Nucleoside',
'Organic acids',
'Others',
'Phenylethanoids',
'Phenylpropanoids',
'Phytohormones',
'Quinone',
'Terpenoids',
'Vitamins'
]


parents = [
'257',
'',
'Secondary',
'Primary',
'Secondary',
'Primary',
'Primary',
'Primary',
'Primary',
'Primary',
'Primary',
'Primary',
'Secondary',
'Secondary',
'Secondary',
'Secondary',
'Secondary',
'Primary'
]


values = [
'24',
'12',
'17',
'24',
'1',
'35',
'7',
'1',
'14',
'17',
'2',
'145',
'8',
'3',
'60',
'4',
'2',
'3',
'3',
'1',
'2',
'1',
'1',
'2',
'8',
'2',
'2',
'16',
'5',
'1',
'2',
'1',
'17',
'19',
'101',
'1',
'4',
'1',
'1',
'1',
'2',
'3',
'1',
'1',
'5',
'24',
'11',
'1',
'17',
'6',
'2',
'7',
'2',
'9',
'8',
'2',
'3',
'1',
'15',
'37',
'35',
'8',
'17',
'8',
'2',
'1'
]


fig =go.Figure(go.Sunburst(
    labels=labels,
    parents=parents,
    values=values,
    branchvalues="total"
    #marker=dict(line=dict(color="black", width=1))  # contour noir
    #textinfo="label+value"  # ajouter valeurs
))

# Update layout for tight margin
fig.update_layout(margin = dict(t=0, l=0, r=0, b=0))

fig.update_layout(
    width=900,   # adjust width as needed
    height=900,   # adjust height as needed
    sunburstcolorway=px.colors.qualitative.D3,
    extendsunburstcolors=True
)

fig.show()

# %% [markdown]
# # BoLASSO

# %%
labels = [
'Phenylpropanoids',
'Terpenoids',
'Alkaloids',
'Quinone',
'Benzenoids',
'Organic acids',
'Flavonoids',
'Cinnamic acids<br>and derivatives',
'Coumarins'
]


parents = [
' ',
' ',
' ',
' ',
' ',
' ',
'Phenylpropanoids',
'Phenylpropanoids',
'Phenylpropanoids',
]


values = [
'9',
'5',
'4',
'2',
'1',
'1',
'6',
'1',
'2'
]


fig =go.Figure(go.Sunburst(
    labels=labels,
    parents=parents,
    values=values,
    branchvalues="total",
    marker=dict(line=dict(color="black", width=2)), # contour noir
    textfont=dict(size=20),
    textinfo="label+value"  # ajouter valeurs
))

# Update layout for tight margin
fig.update_layout(margin = dict(t=0, l=0, r=0, b=0))

fig.update_layout(
    width=900,   # adjust width as needed
    height=900,   # adjust height as needed
    sunburstcolorway=px.colors.qualitative.Safe,
    extendsunburstcolors=True
)

fig.show()

# %% [markdown]
# # BoLASSO V2

# %% [markdown]
# ## Lemon HLB vs control

# %%
labels = [
'Phenylpropanoids',
'Terpenoids',
'Carbohydrates',
'Others',
'Flavonoids',
'Cinnamic acids<br>and derivatives',
'Lignans',
'Triterpenoids',
'Terpenoids precursor'
]


parents = [
' ',
' ',
' ',
' ',
'Phenylpropanoids',
'Phenylpropanoids',
'Phenylpropanoids',
'Terpenoids',
'Terpenoids'
]


values = [
'3',
'3',
'1',
'1',
'1',
'1',
'1',
'2',
'1'
]


fig =go.Figure(go.Sunburst(
    labels=labels,
    parents=parents,
    values=values,
    branchvalues="total",
    marker=dict(line=dict(color="black", width=2)), # contour noir
    textfont=dict(size=20),
    textinfo="label+value"  # ajouter valeurs
))

fig.update_traces(
    textfont_size=26   # augmente la taille ici
)

# Update layout for tight margin
fig.update_layout(margin = dict(t=0, l=0, r=0, b=0))

fig.update_layout(
    width=900,   # adjust width as needed
    height=900,   # adjust height as needed
    sunburstcolorway=px.colors.qualitative.Safe,
    extendsunburstcolors=True
)

fig.show()

# %% [markdown]
# ## Lemon vs orange HLB

# %%
labels = [
'Phenylpropanoids',
'Terpenoids',
'Alkaloids',
'Carbohydrates',
'Others',
'Flavonoids',
'Cinnamic acids<br>and derivatives',
'Triterpenoids',
]


parents = [
' ',
' ',
' ',
' ',
' ',
'Phenylpropanoids',
'Phenylpropanoids',
'Terpenoids',
]


values = [
'7',
'1',
'1',
'1',
'1',
'6',
'1',
'1',
]


fig =go.Figure(go.Sunburst(
    labels=labels,
    parents=parents,
    values=values,
    branchvalues="total",
    marker=dict(line=dict(color="black", width=2)), # contour noir
    textfont=dict(size=20),
    textinfo="label+value"  # ajouter valeurs
))

fig.update_traces(
    textfont_size=26   # augmente la taille ici
)

# Update layout for tight margin
fig.update_layout(margin = dict(t=0, l=0, r=0, b=0))

fig.update_layout(
    width=900,   # adjust width as needed
    height=900,   # adjust height as needed
    sunburstcolorway=px.colors.qualitative.Safe,
    extendsunburstcolors=True
)

fig.show()

# %% [markdown]
# ## Orange

# %%
labels = [
    'A',
    'B',
    'Phenylpropanoids',
    'Terpenoids',
    'Phytohormones',
    'Others',
    'Phenylpropanoids ',
    'Terpenoids ',
    'Carbohydrates',
    'Flavonoids',
    'Coumarins',
    'Cinnamic acids<br>and derivatives',
    'Cytokinins',
    'Monoterpenoids',
    'Cinnamic acids<br>and derivatives ',
    'Flavonoids ',
    'Lignans',
    'Monoterpenoids ',
    'Triterpenoids'
]


parents = [
    '',
    '',
    'A',
    'A',
    'A',
    'A',
    'B',
    'B',
    'B',
    'Phenylpropanoids',
    'Phenylpropanoids',
    'Phenylpropanoids',
    'Phytohormones',
    'Terpenoids',
    'Phenylpropanoids ',
    'Phenylpropanoids ',
    'Phenylpropanoids ',
    'Terpenoids ',
    'Terpenoids '
]


values = [
    '12',
    '7',
    '9',
    '1',
    '1',
    '1',
    '4',
    '2',
    '1',
    '6',
    '1',
    '2',
    '1',
    '1',
    '1',
    '1',
    '2',
    '1 ',
    '1'
]


fig =go.Figure(go.Sunburst(
    labels=labels,
    parents=parents,
    values=values,
    branchvalues="total",
    marker=dict(line=dict(color="black", width=2)), # contour noir
    textfont=dict(size=20),
    textinfo="label+value"  # ajouter valeurs
))

fig.update_traces(
    textfont_size=26   # augmente la taille ici
)

# Update layout for tight margin
fig.update_layout(margin = dict(t=0, l=0, r=0, b=0))

fig.update_layout(
    width=900,   # adjust width as needed
    height=900,   # adjust height as needed
    sunburstcolorway=px.colors.qualitative.Safe,
    extendsunburstcolors=True
)

fig.show()

# %%
A = 'Orange vs<br>Lemon infected'
B = 'Orange control<br>vs infected'

labels = [
    A,
    B,
    'Phenylpropanoids',
    'Terpenoids',
    'Phytohormones',
    'Others',
    'Phenylpropanoids ',
    'Terpenoids ',
    'Carbohydrates',
    'Flavonoids',
    'Coumarins',
    'Cinnamic acids<br>and derivatives',
    'Cytokinins',
    'Monoterpenoids',
    'Cinnamic acids<br>and derivatives ',
    'Flavonoids ',
    'Lignans',
    'Monoterpenoids ',
    'Triterpenoids'
]


parents = [
    '',
    '',
    A,
    A,
    A,
    A,
    B,
    B,
    B,
    'Phenylpropanoids',
    'Phenylpropanoids',
    'Phenylpropanoids',
    'Phytohormones',
    'Terpenoids',
    'Phenylpropanoids ',
    'Phenylpropanoids ',
    'Phenylpropanoids ',
    'Terpenoids ',
    'Terpenoids '
]


values = [
    '12',
    '7',
    '9',
    '1',
    '1',
    '1',
    '4',
    '2',
    '1',
    '6',
    '1',
    '2',
    '1',
    '1',
    '1',
    '1',
    '2',
    '1 ',
    '1'
]


fig =go.Figure(go.Sunburst(
    labels=labels,
    parents=parents,
    values=values,
    branchvalues="total",
    marker=dict(line=dict(color="black", width=2)), # contour noir
    textfont=dict(size=20),
    textinfo="label+value"  # ajouter valeurs
))

fig.update_traces(
    textfont_size=26   # augmente la taille ici
)

# Update layout for tight margin
fig.update_layout(margin = dict(t=0, l=0, r=0, b=0))

fig.update_layout(
    width=900,   # adjust width as needed
    height=900,   # adjust height as needed
    #sunburstcolorway=px.colors.qualitative.Safe,
    sunburstcolorway=px.colors.qualitative.T10,
    extendsunburstcolors=True
)

fig.show()
